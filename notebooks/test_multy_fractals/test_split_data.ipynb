# %%
import numpy as np
from matplotlib import pyplot as plt
from parsivel import pars_read_from_pickle
from multifractal_analysis.general import split_field, pad_to_power_of_2
pars_obj = pars_read_from_pickle("/home/debian-mmss/stage_project/data/saved_events/pasivel01.obj")

# %%
field = pars_obj.rain_rate
plt.plot(field)

# %%
plt.plot(pad_to_power_of_2(field))

# %%
figure = plt.figure()
new_fields = split_field(field,6, 17.0)
n = int(np.ceil(len(new_fields)**0.5))
figure.set_size_inches((4*n,4*n))
for i, f in enumerate(new_fields):
    ax = figure.add_subplot(n,n,i+1)
    ax.plot(f)

# %%
figure = plt.figure()
ax = figure.add_subplot()
x, y = np.log(k), np.log(E)
line = RegressionSolution(x,y)
a,b = line.angular_coef, line.linear_coef
ax.scatter(x,y)
ax.plot((0,6), (b, 6*a + b), 'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> figure = plt.figure()
#       <a href='vscode-notebook-cell:/home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> ax = figure.add_subplot()
# ----> <a href='vscode-notebook-cell:/home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> x, y = np.log(k), np.log(E)
#       <a href='vscode-notebook-cell:/home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> line = RegressionSolution(x,y)
#       <a href='vscode-notebook-cell:/home/debian-mmss/stage_project/mytoolbox/notebooks/test_multy_fractals/test_split_data.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> a,b = line.angular_coef, line.linear_coef
#
# NameError: name 'k' is not defined
